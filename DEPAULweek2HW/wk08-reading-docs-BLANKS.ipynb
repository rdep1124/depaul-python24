# %% [markdown]
# ## Scraping Content from Documents
#
# [This a folder](https://drive.google.com/file/d/1a_JlM2k_An8CT0MRLYjX6gzYvNm5t3cl/view?usp=share_link) that contains more than two dozen files.
#
# Using the lesson on collecting content from documents, please do the following using Python:
#
# * Analyze ONLY the .txt files (but do not physically remove the other files from this folder).
#
# * Output a CSV file that has 4 columns: year, cognition_related , medical_condition, care_hours
#
# * In the cognition_related column, enter ```True``` if the condition is related to Dementia or Alzheimer's disease. ```False``` if it is not.
#
# * In the medical_conditions column, enter either “Dementia" or “Alzheimer’s" or “Not Specified” depending on the case.
# * In the care_hours column, enter either "half-day" for 12-hour care, "full-day" for 24-hour care or “Not Specified"
#
# * Export the CSV to your downloads.

# %%
import glob
import pandas as pd

# %%
target_files = sorted(glob.glob("python1021/hw8/project-docs/*txt"))
target_files
# Out:
# ['python1021/hw8/project-docs/decision_01.txt',
#  'python1021/hw8/project-docs/decision_02.txt',
#  'python1021/hw8/project-docs/decision_03.txt',
#  'python1021/hw8/project-docs/decision_04.txt',
#  'python1021/hw8/project-docs/decision_05.txt',
#  'python1021/hw8/project-docs/decision_06.txt',
#  'python1021/hw8/project-docs/decision_07.txt',
#  'python1021/hw8/project-docs/decision_08.txt',
#  'python1021/hw8/project-docs/decision_09.txt',
#  'python1021/hw8/project-docs/decision_10.txt',
#  'python1021/hw8/project-docs/decision_11.txt',
#  'python1021/hw8/project-docs/decision_12.txt',
#  'python1021/hw8/project-docs/decision_13.txt',
#  'python1021/hw8/project-docs/decision_14.txt',
#  'python1021/hw8/project-docs/decision_15.txt',
#  'python1021/hw8/project-docs/decision_16.txt',
#  'python1021/hw8/project-docs/decision_17.txt',
#  'python1021/hw8/project-docs/decision_18.txt',
#  'python1021/hw8/project-docs/decision_19.txt',
#  'python1021/hw8/project-docs/decision_20.txt']

# %%
care_list = []
for target_file in target_files:
    with open(target_file, "r") as my_text:
        all_text = my_text.readlines()
        year = all_text[0].replace("Year: ", "").rstrip()
        cognition = all_text[2]
        if "not" in cognition:
            cognition = "False"
        else:
            cognition = "True"
        print(f"The patient suffers from {cognition}")
        medical_condition = all_text[2]
        if "Dementia" in medical_condition:
            medical_condition = "Dementia"
        elif "Alzheimer's" in medical_condition:
            medical_condition = "Alzheimer's"
        else:
            medical_condition = "Not specified"
        care_hours = all_text[4]
        if "12-hour care" in care_hours:
            care_hours = "half day"
        elif "24-hour care" in care_hours:
            care_hours = "full-day"
        else:
            care_hours = "Not specified"
        care_list.append({"year": year,
                         "cognition": cognition,
                         "medical_condition": medical_condition,
                         "care_hours": care_hours})

care_list
# Out:
# The patient suffers from True
# The patient suffers from False
# The patient suffers from True
# The patient suffers from False
# The patient suffers from True
# The patient suffers from True
# The patient suffers from False
# The patient suffers from True
# The patient suffers from True
# The patient suffers from True
# The patient suffers from True
# The patient suffers from False
# The patient suffers from True
# The patient suffers from True
# The patient suffers from True
# The patient suffers from True
# The patient suffers from False
# The patient suffers from True
# The patient suffers from True
# The patient suffers from True
# [{'year': '2016',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2017',
#   'cognition': 'False',
#   'medical_condition': 'Dementia',
#   'care_hours': 'Not specified'},
#  {'year': '2021',
#   'cognition': 'True',
#   'medical_condition': "Alzheimer's",
#   'care_hours': 'full-day'},
#  {'year': '2021',
#   'cognition': 'False',
#   'medical_condition': 'Dementia',
#   'care_hours': 'Not specified'},
#  {'year': '2018',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'half day'},
#  {'year': '2021',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'half day'},
#  {'year': '2019',
#   'cognition': 'False',
#   'medical_condition': 'Dementia',
#   'care_hours': 'Not specified'},
#  {'year': '2016',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2014',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2016',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2019',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2019',
#   'cognition': 'False',
#   'medical_condition': 'Dementia',
#   'care_hours': 'Not specified'},
#  {'year': '2021',
#   'cognition': 'True',
#   'medical_condition': "Alzheimer's",
#   'care_hours': 'full-day'},
#  {'year': '2018',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'half day'},
#  {'year': '2013',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'half day'},
#  {'year': '2020',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'half day'},
#  {'year': '2016',
#   'cognition': 'False',
#   'medical_condition': 'Dementia',
#   'care_hours': 'Not specified'},
#  {'year': '2017',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2020',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'},
#  {'year': '2017',
#   'cognition': 'True',
#   'medical_condition': 'Dementia',
#   'care_hours': 'full-day'}]

# %%
df = pd.DataFrame(care_list)
df
# Out:
#     year cognition medical_condition     care_hours
# 0   2016      True          Dementia       full-day
# 1   2017     False          Dementia  Not specified
# 2   2021      True       Alzheimer's       full-day
# 3   2021     False          Dementia  Not specified
# 4   2018      True          Dementia       half day
# 5   2021      True          Dementia       half day
# 6   2019     False          Dementia  Not specified
# 7   2016      True          Dementia       full-day
# 8   2014      True          Dementia       full-day
# 9   2016      True          Dementia       full-day
# 10  2019      True          Dementia       full-day
# 11  2019     False          Dementia  Not specified
# 12  2021      True       Alzheimer's       full-day
# 13  2018      True          Dementia       half day
# 14  2013      True          Dementia       half day
# 15  2020      True          Dementia       half day
# 16  2016     False          Dementia  Not specified
# 17  2017      True          Dementia       full-day
# 18  2020      True          Dementia       full-day
# 19  2017      True          Dementia       full-day

# %%
df.to_csv("care_list.csv", index=False)
